# %% [markdown]
# <a href="https://colab.research.google.com/github/arezoosh/PhD-Course1/blob/master/Thursday_Working%20with%20long%20texts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# q2
# The link below holds a datasewt with ~10k #OKBoomer tweets from the days 10-21 Nov.

# https://github.com/CALDISS-AAU/sdsphd19_coursematerials/raw/master/data/tweets_boomer.zip

# Use elements from the above code to make a list of the most common hashtags (you have to get the hashtags from the text, not using the column containing them already)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1) #to see more text

import numpy as np
import seaborn as sns

import itertools
from collections import Counter

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

# %%
# download and open some boomer tweets from trump_tweet_data_archive

boomer_tweets_df = pd.read_json('https://github.com/CALDISS-AAU/sdsphd19_coursematerials/raw/master/data/tweets_boomer.zip')

# %%
# Reset index (not really needed but why not)
boomer_tweets_df = boomer_tweets_df.set_index(pd.to_datetime(boomer_tweets_df.created_at))
boomer_tweets_df
# Out:
#                                       id      conversation_id  ... retweet_date lang
# created_at                                                     ...
# 2019-11-21 20:28:24  1197612747715837952  1197612747715837952  ...               en
# 2019-11-21 20:27:37  1197612550403297280  1197612550403297280  ...               en
# 2019-11-21 20:26:11  1197612190867476480  1197611882955325440  ...               en
# 2019-11-21 20:24:34  1197611782669402112  1197611782669402112  ...               en
# 2019-11-21 20:23:54  1197611614687637504  1197611614687637504  ...               en
# ...                                  ...                  ...  ... ..            ..
# 2019-11-11 13:12:53  1193879268263989248  1193879268263989248  ...               en
# 2019-11-11 13:11:46  1193878986125971456  1193878986125971456  ...               en
# 2019-11-11 13:09:38  1193878449556881408  1193878449556881408  ...               en
# ...

# %%
# Let's identify people hashtag
boomer_tweets_df['rehashtags'] = boomer_tweets_df['tweet'].map(lambda textline: [tag for tag in tknzr.tokenize(textline) if tag.startswith('#')])

# %%
# Only keep tweets where a mention i present
boomer_tweets_df = boomer_tweets_df[boomer_tweets_df['rehashtags'].map(len) > 0]

# %%
# Collect
boomer_tags = itertools.chain(*boomer_tweets_df['rehashtags'])
taglist = list(set(boomer_tags))

# %%
taglist
# Out:
# ['#marvelsuperheroes',
#  '#2020',
#  '#beamazing',
#  '#resisters',
#  '#JoJosBizarreAdventure',
#  '#UWRF230',
#  '#captainswiss',
#  '#JuanGuaido',
#  '#BabyBoomers',
#  '#ChangeMyMind',
#  '#DonCherrySucksCocksAndDicks',
#  '#GoFuckYourself',
#  '#jimcornette',
#  '#multilevelmarketing',
#  '#craft',
#  '#oops',
#  '#FridayVibes',
#  '#bratpack',
#  '#eeoc',
#  '#boomerfragility',
#  '#fax',
#  '#ReleaseTheSnyderCut',
#  '#Movember',
#  '#antiabortion',
#  '#bust',
#  '#piano',
#  '#suresnowflake',
#  '#generationkaren',
#  '#Diversity',
#  '#makeup',
#  '#computersimulations',
#  '#TheMuttArtist',
#  '#ClimateChangeIsReal',
#  '#BTSBreakTheInternet',
#  '#tiktok',
#  '#TFATK',
#  '#Poland',
#  '#tamagotchi',
#  '#StandwithHK',
#  '#ddoom_memes',
#  '#Marvel',
#  '#retailproblems',
#  '#ArronBanks',
#  '#nobs',
#  '#MicroGen',
#  '#teamstreamqueens',
#  '#HongKong',
#  '#BS',
#  '#MillionDollars',
#  '#internetmarketing',
#  '#ComingSoon',
#  '#PrinceAndrewbbc',
# ...

# %%
counted_tags = Counter(taglist)
#counted_tags
counted_tags.most_common()[:]
#counted_tags.most_common()
# Out:
# [('#marvelsuperheroes', 1),
#  ('#2020', 1),
#  ('#beamazing', 1),
#  ('#resisters', 1),
#  ('#JoJosBizarreAdventure', 1),
#  ('#UWRF230', 1),
#  ('#captainswiss', 1),
#  ('#JuanGuaido', 1),
#  ('#BabyBoomers', 1),
#  ('#ChangeMyMind', 1),
#  ('#DonCherrySucksCocksAndDicks', 1),
#  ('#GoFuckYourself', 1),
#  ('#jimcornette', 1),
#  ('#multilevelmarketing', 1),
#  ('#craft', 1),
#  ('#oops', 1),
#  ('#FridayVibes', 1),
#  ('#bratpack', 1),
#  ('#eeoc', 1),
#  ('#boomerfragility', 1),
#  ('#fax', 1),
#  ('#ReleaseTheSnyderCut', 1),
#  ('#Movember', 1),
#  ('#antiabortion', 1),
#  ('#bust', 1),
#  ('#piano', 1),
#  ('#suresnowflake', 1),
#  ('#generationkaren', 1),
#  ('#Diversity', 1),
#  ('#makeup', 1),
#  ('#computersimulations', 1),
#  ('#TheMuttArtist', 1),
#  ('#ClimateChangeIsReal', 1),
#  ('#BTSBreakTheInternet', 1),
#  ('#tiktok', 1),
#  ('#TFATK', 1),
#  ('#Poland', 1),
#  ('#tamagotchi', 1),
#  ('#StandwithHK', 1),
#  ('#ddoom_memes', 1),
#  ('#Marvel', 1),
# ...
